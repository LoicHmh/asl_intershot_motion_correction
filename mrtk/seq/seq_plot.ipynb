# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
if os.path.exists('/Users/minhao/Projects/mr-recon/pycode'):
    print('runing on MBP...')
    os.chdir('/Users/minhao/Projects/mr-recon/pycode')
else:
    print('Can not find scripts')
    exit(1)
from mrtk.recon.samp_mask import SampMask
# Out:
# runing on MBP...

# %%
from mrtk.seq.seq_design import GRASE3DCAIPI, VERBOSE

myROInfo = GRASE3DCAIPI(
    matrix_size=[64, 64, 32],
    turbo_factor=8,
    epi_factor=64,
    n_segments=4,
    R_factor=4,
    Rz=4,
    Ry=1,
    Dz=1,
    flag_echo_shift=True,
    verbose=VERBOSE.DEBUG,
    )

myROInfo.display_readout_table(
    segments_to_plot=[3], 
    # y_range=(24, 32), 
    # z_range=(10, 18),
    y_range=(0, 8),
    z_range=(0, 8),
    show_arrows=False,
    show_time=False,
    show_colorbar=False,
    figsize_scale=4,
    )
# Out:
# 64, 32, self.turbo_factor = 8, self.epi_factor = 64, self.n_segments = 4
# DEBUG: Using 3D GRASE CAIPI readout order strategy

# %%
from mrtk.seq.seq_design import GRASE3DCAIPI, VERBOSE

myROInfo = GRASE3DCAIPI(
    matrix_size=[64, 64, 32],
    turbo_factor=8,
    epi_factor=64,
    n_segments=4,
    R_factor=4,
    Rz=4,
    Ry=1,
    Dz=2,
    flag_echo_shift=True,
    verbose=VERBOSE.DEBUG,
    )

myROInfo.display_readout_table(
    segments_to_plot=[0], 
    y_range=(24, 36), 
    z_range=(10, 22),
    show_arrows=True,
    show_time=True,
    show_colorbar=True,
    figsize_scale=8,
    )

myROInfo.display_psf()
# Out:
# 64, 32, self.turbo_factor = 8, self.epi_factor = 64, self.n_segments = 4
# DEBUG: Using 3D GRASE CAIPI readout order strategy
# ({'Method': ['', ''],
#   'Type': ['On-resonance', 'Off-resonance'],
#   'Effective Resolution z': [1.783476550767963, 1.7834765505747718],
#   'Effective Resolution y': [1.0562846889809663, 1.2648027259164074],
#   'Specificity': [0.3496069601605042, 0.20864296929993797],
#   'Second Lobe Ratio': [0.06787378212793246, 0.06787378215123765],
#   'Center Peak': [array([16, 32]), array([16, 29])],
#   'Center Shift': [0, 3.0]},
#  <pandas.io.formats.style.Styler at 0x31acf5810>)

# %%
from mrtk.seq.seq_design import GRASE3DCAIPI, VERBOSE

myROInfo = GRASE3DCAIPI(
    matrix_size=[64, 64, 32],
    turbo_factor=16,
    epi_factor=32,
    n_segments=4,
    R_factor=4,
    Rz=2,
    Ry=2,
    Dz=1,
    flag_echo_shift=True,
    verbose=VERBOSE.DEBUG,
    )

myROInfo.display_readout_table(
    segments_to_plot=[0], 
    y_range=(24, 36), 
    z_range=(10, 22),
    show_arrows=True,
    show_time=True,
    show_colorbar=True,
    figsize_scale=8,
    )
# Out:
# 64, 32, self.turbo_factor = 16, self.epi_factor = 32, self.n_segments = 4
# DEBUG: Using 3D GRASE CAIPI readout order strategy

# %%
from mrtk.seq.seq_design import GRASE3D, VERBOSE

myROInfo = GRASE3D(
    matrix_size=[64, 64, 32],
    turbo_factor=8,
    epi_factor=64,
    n_segments=4,
    verbose=VERBOSE.DEBUG,
    )

myROInfo.display_readout_table(
    segments_to_plot=[0], 
    y_range=(24, 36), 
    z_range=(10, 22),
    show_arrows=True,
    show_time=True,
    show_colorbar=True,
    figsize_scale=8,
    )
# Out:
# 64, 32, self.turbo_factor = 8, self.epi_factor = 64, self.n_segments = 4
# DEBUG: Using 3D GRASE JW_CENTRIC readout order strategy
# DEBUG: Partition order in segment 0: [15 13 11  9  7  5  3  1]
# DEBUG: Partition order in segment 1: [16 18 20 22 24 26 28 30]
# DEBUG: Partition order in segment 2: [14 12 10  8  6  4  2  0]
# DEBUG: Partition order in segment 3: [17 19 21 23 25 27 29 31]

# %%
from mrtk.seq.seq_design import GRASE3DCAIPI, VERBOSE

myROInfo = GRASE3DCAIPI(
    matrix_size=[112, 112, 64],
    turbo_factor=8,
    epi_factor=56,
    n_segments=16,
    R_factor=16,
    Rz=8,
    Ry=2,
    Dz=3,
    flag_echo_shift=True,
    verbose=VERBOSE.DEBUG,
    )

myROInfo.display_readout_table(
    segments_to_plot=[3], 
    # y_range=(24, 48), 
    # z_range=(8, 24),
    show_arrows=True,
    show_colorbar=True
    )
# Out:
# 112, 64, self.turbo_factor = 8, self.epi_factor = 56, self.n_segments = 16
# DEBUG: Using 3D GRASE CAIPI readout order strategy
